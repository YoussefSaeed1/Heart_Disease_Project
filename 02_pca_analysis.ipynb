# %% [markdown]
# # 02 – PCA Analysis
#
# Apply PCA on preprocessed features, visualize explained variance and 2D scatter.

# %%
# --- 5. Preprocess data for PCA ---
X_proc = preprocessor.fit_transform(X)
X_proc_dense = X_proc.toarray() if hasattr(X_proc, "toarray") else X_proc

# --- 6. PCA ---
pca = PCA(n_components=None, random_state=42)
X_pca = pca.fit_transform(X_proc_dense)

expl_var = pca.explained_variance_ratio_
cum_var = expl_var.cumsum()

# --- 7. Plot cumulative variance ---
plt.figure(figsize=(8,5))
plt.plot(range(1, len(expl_var)+1), cum_var, marker='o')
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Explained Variance")
plt.title("PCA – Cumulative Explained Variance")
plt.grid(True)
plt.show()

# --- 8. Plot first two components if available ---
if X_pca.shape[1] >= 2:
    plt.figure(figsize=(7,5))
    scatter = plt.scatter(X_pca[:,0], X_pca[:,1], c=y, alpha=0.7, cmap='viridis')
    plt.xlabel("PC1")
    plt.ylabel("PC2")
    plt.title("PCA – First Two Components")
    plt.colorbar(scatter, label="Target")
    plt.show()
